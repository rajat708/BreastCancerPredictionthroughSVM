# %%
import numpy as np
from sklearn import preprocessing, cross_validation, svm
import pandas as pd
from scipy.stats import zscore
import matplotlib.pyplot as plt
from matplotlib import style
from collections import Counter
from scipy.spatial import distance as dis

df = pd.read_csv('data.csv')

#print(df)

# %%
def knn(data, predict, k=3):
    if len(data) >= k:
       
    distances = [];
    j = 0
    for group in data:
        manhatten = 0
        
        
        for features in data[group]:
              
                
                    manhatten  = dis.cityblock(np.array(predict),np.array(features)) 
                    distances.append([manhatten, group])

 
    votes = [i[1] for i in sorted(distances)[:k]]

    #i is the group. i[1] is the point nearest to i[0]
    #[:k] = subsetting list from start to k
    #this one liner above would be equivalent to
    # votes = []
    #for i in sorted(distances)[:k]
    #    votes.append(i[1])
    vote_result = Counter(votes).most_common(1)[0][0]
    
    #Counter(votes).most_common(1) is a list of a tuple.
    #we only want the most common result. most_common(1)
    return vote_result

# %%
#data_set = df.drop(['id'],1, inplace=True)
data_set = df.drop(['id', 'Unnamed: 32'],axis=1)
test_size = 0.8

data_train = data_set[:int(test_size*len(data_set))]
data_test = data_set[int(test_size*len(data_set)):]


#print(data_set)

#X = data_set.drop('diagnosis', axis=1)
X = data_train[['radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'concavity_worst', 'concave points_worst']]

data_train.loc[data_train["diagnosis"]=="M","diagnosis"] = 1
data_train.loc[data_train["diagnosis"]=="B","diagnosis"] = 0 

x = data_train.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
data_train1 = pd.DataFrame(x_scaled)
data_train1.columns = ['diagnosis','radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dumension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']
data_train2 = data_train1[['diagnosis','radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'concavity_worst', 'concave points_worst']]


test = data_test[['diagnosis','radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'concavity_worst', 'concave points_worst']]
test.ix[test.diagnosis == 'M', 'diagnosis'] = 1
test.ix[test.diagnosis == 'B', 'diagnosis'] = 0


#Min-max
min_max_scaler = preprocessing.MinMaxScaler()
X_scaled = min_max_scaler.fit_transform(X)
X = pd.DataFrame(X_scaled)

#Z-Score
#X = X.apply(zscore)

test_scaled = min_max_scaler.fit_transform(test)
test = pd.DataFrame(test_scaled)
test.columns = ['diagnosis','radius_worst','texture_worst','perimeter_worst','area_worst','concavity_worst','concave points_worst']

test_set = {1:[], 0:[]}
train_set = {1:[],0:[]}
for key,values in test.iterrows():
    test_set[values['diagnosis']].append(values["radius_worst":"concave points_worst"])
     
for key,values in data_train2.iterrows():
    train_set[values['diagnosis']].append(values["radius_worst":"concave points_worst"])
 


y = pd.DataFrame(np.array(data_train['diagnosis']), columns=['diagnosis'])

y.ix[y.diagnosis == 'M', 'diagnosis'] = 1
y.ix[y.diagnosis == 'B', 'diagnosis'] = 0

y = y['diagnosis'].astype(str).astype(int)

#print(y.dtypes, X.dtypes)

#print(y)
# Out:
# C:\Users\pc\Anaconda2\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.3)

clf = svm.SVC(C=2.0,kernel='rbf', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=False)
right = list()
wrong = list()
X1 = list()
X2 = list()
clf.fit(X_train, y_train)
total = 0 ;
correct= 0 ;
count =0 ;
thresh = 0.2
for group in test_set:
    for data in test_set[group]:
        
          
    

        distance = clf.decision_function(data)
        arr = np.array(distance)
        
  
        if abs(arr[0]) < thresh:
            count = count + 1 
            vote = knn(train_set,data,14)
            if group == vote:
                correct += 1
                print("correct")
            
            
        else:
            vote = clf.predict([data])
   
            if group == vote:
                correct += 1
            
            
            
        
        total  += 1     
        

print(total)

print(correct)
print(count)
accuracy = clf.score(X_train,y_train)
# Out:
# correct
# correct
# correct
# correct
# correct
# correct
# 114
# 113
# 6
# C:\Users\pc\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\pc\Anaconda2\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ...
